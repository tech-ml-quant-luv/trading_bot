# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("market_data.db")

# list tables
tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)
print(tables)

# inspect one table
df = pd.read_sql("SELECT * FROM features_infy", conn).set_index("datetime")
print(df)

conn.close()
# Out:
#                   name
# 0              candles
# 1        features_infy
# 2    features_reliance
# 3  features_adaniports
# 4   features_icicibank
#                              open    high     low   close  volume  resistance  \
# datetime
# 2026-01-29 12:05:00+05:30  1649.2  1649.7  1647.0  1648.4   19272         NaN
# 2026-01-29 12:10:00+05:30  1648.4  1649.5  1646.1  1648.5   50240         NaN
# 2026-01-29 12:15:00+05:30  1648.5  1649.0  1645.3  1646.4   16606         NaN
# 2026-01-29 12:20:00+05:30  1646.8  1649.8  1646.4  1648.9   81608         NaN
# 2026-01-29 12:25:00+05:30  1649.3  1650.9  1648.1  1650.3   43045         NaN
# ...                           ...     ...     ...     ...     ...         ...
# 2026-02-03 11:40:00+05:30  1677.0  1678.4  1676.2  1677.4   32875      1679.7
# 2026-02-03 11:45:00+05:30  1677.5  1678.5  1676.5  1677.5   27124      1679.7
# 2026-02-03 11:50:00+05:30  1677.6  1677.9  1676.7  1677.6   16211      1679.7
# ...
