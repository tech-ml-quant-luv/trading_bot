# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("market_data.db")

# list tables
tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)
print(tables)

# inspect one table
df = pd.read_sql("SELECT * FROM features_hindalco", conn).set_index("datetime")
print(df)

conn.close()
# Out:
#                   name
# 0              candles
# 1        features_infy
# 2    features_reliance
# 3  features_adaniports
# 4   features_icicibank
# 5    features_hindalco
#                               open     high      low    close  volume  \
# datetime
# 2026-01-29 15:05:00+05:30  1023.30  1024.25  1022.35  1023.00  449590
# 2026-01-29 15:10:00+05:30  1023.10  1024.90  1023.10  1024.10  293705
# 2026-01-29 15:15:00+05:30  1024.10  1026.05  1024.10  1025.10  355957
# 2026-01-29 15:20:00+05:30  1025.00  1026.15  1024.60  1026.00  329836
# 2026-01-29 15:25:00+05:30  1025.95  1027.00  1023.30  1027.00  241959
# ...                            ...      ...      ...      ...     ...
# 2026-02-03 14:40:00+05:30   960.25   960.70   958.15   959.40  113552
# 2026-02-03 14:45:00+05:30   959.45   962.15   958.75   961.00  115809
# 2026-02-03 14:50:00+05:30   961.00   961.85   959.90   959.90   72734
# 2026-02-03 14:55:00+05:30   959.80   960.70   958.70   958.90   82458
# ...

# %%
df
# Out:
#                               open     high      low    close  volume  \
# datetime
# 2026-01-29 15:05:00+05:30  1023.30  1024.25  1022.35  1023.00  449590
# 2026-01-29 15:10:00+05:30  1023.10  1024.90  1023.10  1024.10  293705
# 2026-01-29 15:15:00+05:30  1024.10  1026.05  1024.10  1025.10  355957
# 2026-01-29 15:20:00+05:30  1025.00  1026.15  1024.60  1026.00  329836
# 2026-01-29 15:25:00+05:30  1025.95  1027.00  1023.30  1027.00  241959
# ...                            ...      ...      ...      ...     ...
# 2026-02-03 14:40:00+05:30   960.25   960.70   958.15   959.40  113552
# 2026-02-03 14:45:00+05:30   959.45   962.15   958.75   961.00  115809
# 2026-02-03 14:50:00+05:30   961.00   961.85   959.90   959.90   72734
# 2026-02-03 14:55:00+05:30   959.80   960.70   958.70   958.90   82458
# 2026-02-03 15:00:00+05:30   959.05   959.05   959.00   959.05    2511
#
#                            resistance  support  prev_close    tr       atr  \
# datetime
# ...
